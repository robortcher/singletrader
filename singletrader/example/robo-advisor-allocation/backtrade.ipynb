# %%
import sys
sys.path.append('/Users/xiao/work/wealth_dev/singletrader/')
import os 
from singletrader.backtesting.bar import bar_resample
from singletrader.backtesting.account import Account
from singletrader.performance.common import performance_indicator
from strategies import BlackLittermanAllocation
from utils.config import *
from singletrader.backtesting.engine import Engine
import numpy as np
import pandas as pd
import plotly.express as px
from yahooquery import Ticker
from plotly.figure_factory import create_table
import plotly.io as pio
pio.renderers.default = "notebook_connected"
import warnings
warnings.filterwarnings('ignore')

# %%
w_mkt = pd.Series(1/len(asset_webull),index=asset_webull['ETF'])
target_vol = np.arange(0.05,0.17,0.01)
constraint = lambda x:x<= asset_webull.set_index('ETF').reindex(w_mkt.index)['max_weight'].values
sector_constraint = constraint_state_street
all_etf = asset_webull['ETF'].tolist()
sec_mapper = asset_webull.set_index('ETF')['asset type'].to_dict()
test_sector_mappers = {key:{'sector_mapper':sec_mapper,'sector_upper':constraint_state_street[key]['sector_upper'],'sector_lower':constraint_state_street[key]['sector_lower']} for key in constraint_state_street.keys()}
engine = Engine(universe=all_etf,start_date='2010-01-01',end_date='2022-11-30')

DATA_PATH = r'/Users/xiao/work/wealth_dev/wm-etf-allocation/example/data/ETF'
data_files = os.listdir(DATA_PATH)
local_data = {symbol.replace('_US_Equity.csv',''):pd.read_csv(DATA_PATH+'/'+ symbol) for symbol in data_files}
df = pd.concat(local_data).rename(columns={'Date':'date','OpenPrice':"open",'High':'high','Low':'low','ClosePrice':'close'}).droplevel(1)
df.index.name='symbol'
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date',append=True).swaplevel(0,1)
df_month = bar_resample(df,'MS')
ticker = Ticker(all_etf)
market_data = pd.DataFrame(ticker.summary_detail).T
etf_config = asset_webull.set_index('ETF',drop=False)

# %%
def run(engine):
    for sec_mapper_config in test_sector_mappers:
        account = Account(
            capital_base = 1e8,
            commission_buy = 0.000,
            commission_sell = 0.000,
            margin_ratio = 1,
            min_commission = 0.,
            trade_free = False,
            price_type = 'close',
            slippage = 0.,
            slippage_ratio = 0.,
            tax_buy = 0.,
            tax_sell = 0.00,
            region='us',
        )
        mapper = test_sector_mappers[sec_mapper_config]
        engine.run_backtest(expanding=True,
                            strategy=BlackLittermanAllocation,
                            constraint=constraint,
                            sector_constraint=mapper,
                            has_sector_constraint=True,
                            am_size=70,
                            account=account,
                            w_mkt=w_mkt)
    return engine.get_all_nv()
engine.load_data(src='yahoo', interval="1mo")
nv_yahoo = run(engine)
# Out:
# [*********************100%***********************]  13 of 13 completed
# strategy start...
# strategy start...
# strategy start...
# strategy start...
# strategy start...
# strategy start...

# %%
nv = engine.get_all_nv().drop_duplicates(keep='last')
nv.columns = constraint_state_street.keys()

# %%
px.line(nv,title='net value of different risk level portfolio from 2018.8~2022.11')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="609fa778-f4d9-4500-9e80-1c67d2917f0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("609fa778-f4d9-4500-9e80-1c67d2917f0f")) {                    Plotly.newPlot(                        "609fa778-f4d9-4500-9e80-1c67d2917f0f",                        [{"hovertemplate":"variable=conservative<br>datetime=%{x}<br>value=%{y}<extra></extra>","legendgroup":"conservative","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"conservative","orientation":"v","showlegend":true,"x":["2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00"],"xaxis":"x","y":[1.0,1.0039499279253197,0.9994188239974022,0.9696590683077049,0.9725582029804802,0.9646946944227028,1.0007071341893958,1.0033182680770303,1.0239786463624,1.0293573341591071,1.0257122888637924,1.056232563184986,1.0592886379523658,1.0752939931974983,1.0750720606082727,1.079040551268215,1.0844192010756875,1.0876485475601387,1.1023381412762832,1.087806075574646,1.0186913245718003,1.086878518610611,1.1052648703195953,1.1137828733327866,1.1327404048208236,1.1299640206996535,1.1056562325003434,1.0956359824271775,1.1549577020493698,1.1620539100912857,1.1598487551155472,1.1723172814720917,1.1669681590750502,1.1803853281909942,1.193025460656433,1.2064835691155242,1.2111845991111374,1.2091948441383362,1.2018186782921219,1.2285613100262833,1.2239783949288177,1.2279197583022308,1.2275371981652832,1.2217356417528915,1.2093827008711624,1.1601812192601395,1.1875719830579758,1.1265744099502946,1.1813112976054,1.1484173800941087,1.0741172714966964,1.1129835939266586,1.1593523443800353],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=moderate conservative<br>datetime=%{x}<br>value=%{y}<extra></extra>","legendgroup":"moderate conservative","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"moderate conservative","orientation":"v","showlegend":true,"x":["2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T ...

# %%
create_table(round(performance_indicator(nv,0.02,12),4).reset_index())
# Out:
# <div>                            <div id="9815b2b3-e7b6-4432-9048-db892e4dcb30" class="plotly-graph-div" style="height:410px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9815b2b3-e7b6-4432-9048-db892e4dcb30")) {                    Plotly.newPlot(                        "9815b2b3-e7b6-4432-9048-db892e4dcb30",                        [{"colorscale":[[0,"#00083e"],[0.5,"#ededee"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0,0,0,0,0],[0.5,0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1,1],[0.5,0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1,1],[0.5,0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1,1],[0.5,0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1,1],[0.5,0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1,1],[0.5,0.5,0.5,0.5,0.5,0.5,0.5]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>index</b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>conservative</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>moderate conservative</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>moderate</b>","x":2.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>moderate growth</b>","x":3.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>growth</b>","x":4.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>maximum growth</b>","x":5.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"abs_ret","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.1594","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2531","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3717","x":2.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4502","x":3.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.5232","x":4.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.559","x":5.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"ret_ann","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0347","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0534","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0757","x":2.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0896","x":3.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.102","x":4.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.1079","x":5.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"sigma_ann","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left"," ...

# %%
turnover_ratio = engine.get_all_info('turnover_ratio')
turnover_ratio.columns = constraint_state_street.keys()

# %%
px.line(turnover_ratio.drop_duplicates(keep=False).iloc[1:],title='turnover ratio of different risk level')
# Out:
# <div>                            <div id="91413c37-220d-4c12-8efc-8dadc897b48e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91413c37-220d-4c12-8efc-8dadc897b48e")) {                    Plotly.newPlot(                        "91413c37-220d-4c12-8efc-8dadc897b48e",                        [{"hovertemplate":"variable=conservative<br>datetime=%{x}<br>value=%{y}<extra></extra>","legendgroup":"conservative","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"conservative","orientation":"v","showlegend":true,"x":["2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00"],"xaxis":"x","y":[0.017904722094978055,0.019033849238791162,0.15101966466822583,0.11146566234090481,0.09299771953099403,0.032815110757539546,0.039130743253105095,0.024859983940977107,0.018758225632451025,0.06691290052027313,0.023133632033752117,0.003952133798972833,0.025259158661755,0.07639538746224152,0.030951025477075945,0.015268240463585998,0.03922542443765491,0.034372990665646086,0.13217047959770056,0.07217540220399223,0.06204343212460124,0.011108032755315364,0.009077721480943171,0.017529574392330296,0.014703070020330668,0.03256601993020662,0.00535710071453922,0.05287016329277751,0.010132934293288692,0.0387887949706362,0.12847911143677965,0.10187200532121005,0.04878884627284814,0.09716596878788458,0.07701121055467847,0.1468310574141829,0.09600734958649097,0.25093830497399466,0.04652309153333021,0.06204516390627687,0.09156645382457684,0.09944845739548815,0.027694768736881183,0.13906150978668408,0.12592714858112677,0.03126526506401088,0.03334052690487475,0.012032369863215141,0.015142998899664521,0.09847782409594405,0.13877589338226154],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=moderate conservative<br>datetime=%{x}<br>value=%{y}<extra></extra>","legendgroup":"moderate conservative","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"moderate conservative","orientation":"v","showlegend":true,"x":["2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2 ...

# %%
create_table(round(turnover_ratio.drop_duplicates(keep=False).iloc[1:].describe(),2).reset_index())
# Out:
# <div>                            <div id="944af306-e21b-40db-9e01-31f8cd8906d0" class="plotly-graph-div" style="height:320px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("944af306-e21b-40db-9e01-31f8cd8906d0")) {                    Plotly.newPlot(                        "944af306-e21b-40db-9e01-31f8cd8906d0",                        [{"colorscale":[[0,"#00083e"],[0.5,"#ededee"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0,0,0,0,0],[0.5,0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1,1],[0.5,0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1,1],[0.5,0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1,1],[0.5,0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1,1]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>index</b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>conservative</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>moderate conservative</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>moderate</b>","x":2.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>moderate growth</b>","x":3.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>growth</b>","x":4.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>maximum growth</b>","x":5.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"count","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"51.0","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"51.0","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"51.0","x":2.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"51.0","x":3.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"51.0","x":4.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"51.0","x":5.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"mean","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.06","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.1","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.07","x":2.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.05","x":3.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.02","x":4.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.02","x":5.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"std","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.05","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y ...

# %%
current_weights = engine.get_all_info('current_weights')
current_weights.columns = constraint_state_street.keys()
current_weights = current_weights.rename(asset_webull.set_index('ETF')['sub-asset type'].to_dict())
current_weights = current_weights.stack()
current_weights=  current_weights.reset_index()
current_weights.columns = ['asset','risk level','weights']

# %%
px.bar(current_weights,x='risk level',y='weights',color='asset',title='last asset weights of different risk level')
# Out:
# <div>                            <div id="593e8553-33b8-4f61-be59-003791b5b1f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("593e8553-33b8-4f61-be59-003791b5b1f6")) {                    Plotly.newPlot(                        "593e8553-33b8-4f61-be59-003791b5b1f6",                        [{"alignmentgroup":"True","hovertemplate":"asset=Commodities<br>risk level=%{x}<br>weights=%{y}<extra></extra>","legendgroup":"Commodities","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Commodities","offsetgroup":"Commodities","orientation":"v","showlegend":true,"textposition":"auto","x":["conservative","moderate conservative","moderate","moderate growth","growth","maximum growth"],"xaxis":"x","y":[0.09722673002461475,0.09666658108921747,0.09600662074122118,0.09579359994509007,0.0961323917160858,0.09636176452160622],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"asset=US Govt Bonds<br>risk level=%{x}<br>weights=%{y}<extra></extra>","legendgroup":"US Govt Bonds","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"US Govt Bonds","offsetgroup":"US Govt Bonds","orientation":"v","showlegend":true,"textposition":"auto","x":["conservative"],"xaxis":"x","y":[0.1992986962406968],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"asset=US Corporate Bonds<br>risk level=%{x}<br>weights=%{y}<extra></extra>","legendgroup":"US Corporate Bonds","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"US Corporate Bonds","offsetgroup":"US Corporate Bonds","orientation":"v","showlegend":true,"textposition":"auto","x":["conservative","moderate conservative","moderate","moderate growth","growth"],"xaxis":"x","y":[0.30723447429589745,0.3054593863497322,0.30337734702865304,0.2522570185785403,0.10125749699147611],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"asset=TIPS<br>risk level=%{x}<br>weights=%{y}<extra></extra>","legendgroup":"TIPS","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"TIPS","offsetgroup":"TIPS","orientation":"v","showlegend":true,"textposition":"auto","x":["conservative","moderate conservative","moderate"],"xaxis":"x","y":[0.2936835662014996,0.2919853435715384,0.09666704469061571],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"asset=Dividend Stocks<br>risk level=%{x}<br>weights=%{y}<extra></extra>","legendgroup":"Dividend Stocks","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Dividend Stocks","offsetgroup":"Dividend Stocks","orientation":"v","showlegend":true,"textposition":"auto","x":["conservative","moderate conservative","moderate","moderate growth","growth","maximum growth"],"xaxis":"x","y":[0.10255461935830293,0.3022709306367356,0.30382715082162837,0.3031475200750396,0.3042254413037329,0.30494336430316077],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"asset=US large cap<br>risk level=%{x}<br>weights=%{y}<extra></extra>","legendgroup":"US large cap","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"US large cap","offsetgroup":"US large cap","orientation":"v","showlegend":true,"textposition":"auto","x":["moderate conservative","moderate","moderate growth","growth","maximum growth"],"xaxis":"x","y":[0.0036142939538448974,0.20011909865632913,0.29952730799878746,0.30059111597402516,0.30129892238914135],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"asset=US small cap<br>risk level=%{x}<br>weights=%{y}<extra></extra>","legendgroup":"US small cap","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"US small cap","offsetgroup":"US small cap","orientation":"v","showlegend":true,"textposition":"auto","x":["moderate growth","growth","maximum growth"],"xaxis":"x","y":[0.04927294996759685,0.19779210940954678,0.2973933071715153],"y ...
